# %%
# 설계점 검증 실행
import importlib
import run_design_point

# 모듈을 강제로 다시 로드 (캐시 문제 해결)
importlib.reload(run_design_point)

# 함수 실행
run_design_point.run_design_point_check()
# Out:
# === 설계점(Design Point) 계산 시작 ===
# --- Station 0: Ambient ---
#   T: 518.67 °R
#   P: 14.70 psia
#   h: -4.43 BTU/lbm
#   s: 6,849.54 J/kg-K
#   W: 44.00 pps
# --- Station 2: Inlet Face ---
#   T: 518.67 °R
#   P: 14.70 psia
#   h: -4.43 BTU/lbm
#   s: 6,849.54 J/kg-K
#   W: 44.00 pps
# --- Station 3: Compressor Exit ---
#   T: 954.44 °R
#   P: 102.87 psia
#   h: 102.18 BTU/lbm
#   s: 6,912.18 J/kg-K
#   W: 44.00 pps
#   Compressor Work: 106.61 BTU/lbm
# 경고: _perform_combustion (far=0.001) 계산 실패:
# *******************************************************************************
# CanteraError thrown by ThermoPhase::setState_HPorUV (HP):
# No convergence in 500 iterations
# 	Target Enthalpy         = 40151392.38626709
# 	Current Pressure        = 673813.863184
# 	Starting Temperature    = 300
# 	Current Temperature     = 9376.632690429688
# 	Current Enthalpy        = 37080666.53358518
# 	Current Delta T         = 100
# ...

# %%
import cantera as ct

# %%
help(ct.Solution)
# Out:
# Help on class Solution in module cantera.composite:
#
# class Solution(cantera.transport.Transport, cantera.kinetics.Kinetics, cantera.thermo.ThermoPhase)
#  |  A class for chemically-reacting solutions. Instances can be created to
#  |  represent any type of solution -- a mixture of gases, a liquid solution, or
#  |  a solid solution, for example.
#  |
#  |  Class `Solution` derives from classes `ThermoPhase`, `Kinetics`, and
#  |  `Transport`.  It defines no methods of its own, and is provided so that a
#  |  single object can be used to compute thermodynamic, kinetic, and transport
#  |  properties of a solution.
#  |
#  |  To skip initialization of the Transport object, pass the keyword argument
#  |  ``transport_model=None`` to the `Solution` constructor.
#  |
#  |  The most common way to instantiate `Solution` objects is by using a phase
#  |  definition, species and reactions defined in an input file::
#  |
#  |      gas = ct.Solution('gri30.yaml')
#  |
# ...
